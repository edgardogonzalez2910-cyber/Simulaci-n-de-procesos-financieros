# %% [markdown]
# ## MONTECARLO

# %% [markdown]
# Edgardo Gonzalez

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
def funcion_a_integrar(x):
    return x**2
a= 2
b=5

N= 10000

x=np.random.uniform(a,b,N)
y=np.random.uniform(0,funcion_a_integrar(b),N)

# %%
n_bajo_curva=np.sum(y < funcion_a_integrar(x))
n_bajo_curva
# Out:
# np.int64(5191)

# %%
respuesta=(b-a)*funcion_a_integrar(b)* n_bajo_curva/N
respuesta
# Out:
# np.float64(38.9325)

# %%
plt.plot(x,y,'.')
plt.plot(np.linspace(a,b,100),funcion_a_integrar(np.linspace(a,b,100)),'r')
plt.show()

# %% [markdown]
# ### Actividad

# %%
A=-1
B=1
n=10000
x=np.random.uniform(A,B,n)
y=np.random.uniform(0,funcion_a_integrar(B),n)

ecua=x**2+y**2

dentro_circulos=np.sum(ecua<= 1)
dentro_circulos
# Out:
# np.int64(7757)

# %%
pi= 4* dentro_circulos/n
pi
# Out:
# np.float64(3.1028)
